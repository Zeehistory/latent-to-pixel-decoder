# %% [markdown]
# # 02 · Latent exploration
# Extract latents with the mock encoder and inspect shapes / PCA.

# %%
import sys; sys.path.insert(0,'..')
from src.utils.config import load_config
from src.encoders import build_encoder
import torch
cfg = load_config('../configs/train/smoke_synthetic.yaml')
enc = build_encoder(cfg.encoder)
b = enc.encode(torch.rand(1,16,3,128,128))
print({k:tuple(v.shape) for k,v in b.layers.items()})
