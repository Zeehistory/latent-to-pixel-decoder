# %% [markdown]
# # 05 · Latent interventions
# Discover a physical direction, intervene, and measure decoded controllability (Experiment 6).

# %%
import sys; sys.path.insert(0,'..')
from src.analysis.intervention import discover_direction, intervention_sweep
print('Requires a state-mode decoder; see src/analysis/intervention.py docstring.')
