# %% [markdown]
# # 04 · Physics manifold analysis
# Layerwise CKA, intrinsic dimension, circular direction codes.

# %%
import sys; sys.path.insert(0,'..')
from src.analysis.latent_geometry import layerwise_cka_matrix
print('Provide a latent_dir from run_full_pipeline, then call layerwise_cka_matrix(latent_dir, layers).')
