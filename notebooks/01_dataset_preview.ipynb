# %% [markdown]
# # 01 · Dataset preview
# Generate synthetic physics clips and visualize frames + ground-truth state.

# %%
import sys; sys.path.insert(0,'..')
from src.data.synthetic_physics import SyntheticPhysics
import matplotlib.pyplot as plt
gen = SyntheticPhysics(image_size=64, num_frames=16, scenarios=['bouncing_ball','projectile','collision'])
clip = gen.generate(0)
print('state keys:', clip.state_keys)
fig,ax = plt.subplots(1,8,figsize=(16,2))
for i in range(8): ax[i].imshow(clip.frames[i*2].permute(1,2,0)); ax[i].axis('off')
plt.show()
