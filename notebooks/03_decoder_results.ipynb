# %% [markdown]
# # 03 · Decoder results
# Load a trained decoder checkpoint and render reconstructions (run the smoke pipeline first).

# %%
# See scripts/visualize_reconstructions.py; this notebook wraps it.
import sys; sys.path.insert(0,'..')
print('Run: python ../scripts/run_full_pipeline.py --config ../configs/train/smoke_synthetic.yaml --output_dir ../outputs/smoke')
